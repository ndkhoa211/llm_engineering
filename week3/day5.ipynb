# %% [markdown]
# # Meeting minutes creator
#
# In this colab, we make a meeting minutes program.
#
# It includes useful code to connect your Google Drive to your colab.
#
# Upload your own audio to make this work!!
#
# https://colab.research.google.com/drive/1KSMxOCprsl1QRpt_Rq0UqCAyMtPqDQYx?usp=sharing
#
# This should run nicely on a low-cost or free T4 box.

# %% [markdown]
# ### BUT FIRST - Something cool - really showing you how "model inference" works via OpenAI

# %%
from visualizer import TokenPredictor, create_token_graph, visualize_predictions

message = "In one sentence, describe the color orange to someone who has never been able to see"
model_name = "gpt-4.1-mini"

predictor = TokenPredictor(model_name)
predictions = predictor.predict_tokens(message)
G = create_token_graph(model_name, predictions)
plt = visualize_predictions(G)
plt.show()

# %%
predictions
# Out:
# [{'token': 'Orange',
#   'probability': 0.9999667875258017,
#   'alternatives': [('The', 2.753553023692875e-05),
#    ('Imagine', 5.422067386589378e-06)]},
#  {'token': ' is',
#   'probability': 0.9626542168013442,
#   'alternatives': [(' feels', 0.03732615828765888),
#    (' tastes', 1.8218715975527503e-05)]},
#  {'token': ' the',
#   'probability': 0.9902178135847509,
#   'alternatives': [(' a', 0.005196185528156266),
#    (' like', 0.004585617633852805)]},
#  {'token': ' warm',
#   'probability': 0.9622583424156373,
#   'alternatives': [(' warmth', 0.03731080134279935),
#    (' vibrant', 0.0003228017579640113)]},
#  {'token': ',',
#   'probability': 0.9960650755854227,
#   'alternatives': [(' feeling', 0.0024689989605390494),
#    (' sensation', 0.001029231893274446)]},
#  {'token': ' vibrant',
#   'probability': 0.8508197417303472,
#   'alternatives': [(' energetic', 0.04235981812541515),
#    (' lively', 0.03298985952683561)]},
#  {'token': ' feeling',
#   'probability': 0.866120240269516,
#   'alternatives': [(' sensation', 0.11721662104718271),
#    (' color', 0.01586354460945917)]},
#  {'token': ' of',
#   'probability': 0.9524725491396102,
#   'alternatives': [(' you', 0.04742082051559159),
#    (' like', 9.154374093336164e-05)]},
#  {'token': ' a',
#   'probability': 0.6189550358876159,
#   'alternatives': [(' the', 0.29237366531733827),
#    (' sunlight', 0.08376644760327391)]},
#  {'token': ' gentle',
#   'probability': 0.6204085927291054,
#   'alternatives': [(' sunset', 0.22823557999504454),
#    (' glowing', 0.083963177624017)]},
#  {'token': ' sunset',
#   'probability': 0.5360347350041047,
#   'alternatives': [(' sunrise', 0.4174642713746697),
#    (' sun', 0.014284844383120901)]},
#  {'token': ' or',
#   'probability': 0.41906108638294,
#   'alternatives': [(' on', 0.36982011072668014), ('’s', 0.136049215668092)]},
#  {'token': ' the',
#   'probability': 0.9997627567968599,
#   'alternatives': [(' a', 0.00023050512421550915),
#    (' ripe', 6.1427534917478156e-06)]},
#  {'token': ' sweet',
#   'probability': 0.7802663909942394,
#   'alternatives': [(' bright', 0.105597579319321),
#    (' tang', 0.030254213011809875)]},
#  {'token': ',',
#   'probability': 0.9401822016350603,
#   'alternatives': [(' tang', 0.02839104475644082),
#    (' zest', 0.025055009058699645)]},
#  {'token': ' tang',
#   'probability': 0.8150828427490742,
#   'alternatives': [(' z', 0.1818695679469061),
#    (' bright', 0.0013885914523509722)]},
#  {'token': 'y',
#   'probability': 1.0,
#   'alternatives': [(' of', 7.991959892953932e-11),
#    (' y', 8.878265478459658e-13)]},
#  {'token': ' taste',
#   'probability': 0.9409199601535808,
#   'alternatives': [(' burst', 0.0468456505731815),
#    (' zest', 0.009224453331114164)]},
#  {'token': ' of',
#   'probability': 0.9953274739666047,
#   'alternatives': [(' and', 0.004609280561484096),
#    (' that', 5.802227934324784e-05)]},
#  {'token': ' a',
#   'probability': 0.9762760007706777,
#   'alternatives': [(' ripe', 0.022959810914211728),
#    (' citrus', 0.0004205235053976912)]},
#  {'token': ' ripe',
#   'probability': 0.9921360667481527,
#   'alternatives': [(' fresh', 0.00668496039550239),
#    (' citrus', 0.0005487349648656317)]},
#  {'token': ' citrus',
#   'probability': 0.986465475793821,
#   'alternatives': [(',', 0.012417766465963749),
#    (' t', 0.00042491260209898655)]},
#  {'token': ' fruit',
#   'probability': 0.9999841908314937,
#   'alternatives': [(',', 1.0129929366190528e-05),
#    (' that', 3.2887065628995586e-06)]},
#  {'token': ' that',
#   'probability': 0.4778789711028057,
#   'alternatives': [(',', 0.2257340287524583), ('.', 0.19920958118198645)]},
#  {'token': ' energ',
#   'probability': 0.33680910789228924,
#   'alternatives': [(' bright', 0.2314852888535222),
#    (' fills', 0.18028092422863343)]},
#  {'token': 'izes',
#   'probability': 1.0,
#   'alternatives': [('ize', 1.2256067444099483e-11),
#    ('IZES', 2.413362771833214e-12)]},
#  {'token': ' your',
#   'probability': 0.6501380572913905,
#   'alternatives': [(' and', 0.30710345462368155),
#    (' the', 0.041561933014438175)]},
#  {'token': ' senses',
#   'probability': 0.9964873656062117,
#   'alternatives': [(' spirit', 0.0031716016022154945),
#    (' skin', 0.00026034078901322245)]},
#  {'token': '.',
#   'probability': 0.9557370086576085,
#   'alternatives': [(' with', 0.02546952629452063),
#    (' like', 0.017504936531610383)]}]
